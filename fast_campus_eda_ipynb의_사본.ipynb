# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 코랩
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 런타임 재시작
plt.rc('font', family='NanumBarunGothic')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# The following packages were automatically installed and are no longer required:
#   libnvidia-common-460 nsight-compute-2020.2.0
# Use 'sudo apt autoremove' to remove them.
# 0 upgraded, 0 newly installed, 0 to remove and 42 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
url = '/content/drive/MyDrive/Colab Notebooks/파이널프로젝트_RAW_210329_210926.csv'
data = pd.read_csv(url)
df = pd.DataFrame(data)
df.head()
# Out:
#    Unnamed: 0      id  customer_id  course_id     type      state  \
# 0           0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1           1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2           2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3           3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4           4  970658     478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format         completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원  2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원  2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인  2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인  2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원  2021-03-28 15:21:54
#
#    transaction_amount              coupon_title  coupon_discount_amount  \
# 0               90500                       NaN                     NaN
# 1               96000                       NaN                     NaN
# 2              171810     [10% 할인] 시크릿코드 실무 완성편                 19090.0
# 3              171810                       NaN                     NaN
# 4               97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
#
#    sale_price  tax_free_amount   pg method subcategory_title  \
# 0    110500.0         110500.0  NaN  VBANK           개발자 커리어
# 1    116000.0         116000.0  NaN   CARD             영상 편집
# 2    190900.0         190900.0  NaN   CARD               NaN
# 3    190900.0         190900.0  NaN   CARD               NaN
# 4    117500.0         117500.0  NaN   CARD           PPT/보고서
#
#     marketing_start_at
# 0                  NaN
# 1  2020-12-02 00:00:00
# 2  2021-03-04 00:00:00
# 3  2021-03-04 00:00:00
# 4  2019-11-14 00:00:00

# %%
df.shape
# Out:
# (105419, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 105419 entries, 0 to 105418
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Unnamed: 0              105419 non-null  int64
#  1   id                      105419 non-null  int64
#  2   customer_id             105416 non-null  float64
#  3   course_id               100212 non-null  float64
#  4   type                    105419 non-null  object
#  5   state                   105419 non-null  object
#  6   course_title            105403 non-null  object
#  7   category_title          105395 non-null  object
#  8   format                  105403 non-null  object
#  9   completed_at            105419 non-null  object
#  10  transaction_amount      105419 non-null  int64
#  11  coupon_title            31817 non-null   object
#  12  coupon_discount_amount  31817 non-null   float64
#  13  sale_price              104291 non-null  float64
#  14  tax_free_amount         104291 non-null  float64
#  15  pg                      90344 non-null   object
#  16  method                  92323 non-null   object
#  17  subcategory_title       85590 non-null   object
#  18  marketing_start_at      87440 non-null   object
# dtypes: float64(5), int64(3), object(11)
# memory usage: 15.3+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                    0
# id                            0
# customer_id                   3
# course_id                  5207
# type                          0
# state                         0
# course_title                 16
# category_title               24
# format                       16
# completed_at                  0
# transaction_amount            0
# coupon_title              73602
# coupon_discount_amount    73602
# sale_price                 1128
# tax_free_amount            1128
# pg                        15075
# method                    13096
# subcategory_title         19829
# marketing_start_at        17979
# dtype: int64

# %%
df['category_title'].value_counts()
# Out:
# 프로그래밍       34430
# 데이터사이언스     14076
# 업무 생산성      13323
# 디자인         12009
# 영상/3D       10260
# 마케팅          9857
# 부동산/금융       5523
# 투자/재테크       2501
# 크리에이티브       2250
# 교육           1031
# 지식콘텐츠          56
# 비즈니스           42
# 파이낸스           25
# 데이터 사이언스        9
# 관리              2
# 일러스트            1
# Name: category_title, dtype: int64

# %%
df['coupon_title'].value_counts()
# Out:
# [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                                 5498
# [WELCOME] 온라인 강의 3만원 할인쿠폰                                3206
# [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰                                 2469
# [WELCOME] 온라인 강의 2만원 할인쿠폰                                2325
# [WELCOME] 온라인 강의 1만원 할인쿠폰                                1900
#                                                          ...
# [무료수강권] 한 번에 끝내는 Java/Spring 웹 개발 마스터 초격차 패키지_안성훈 강사님       1
# 오늘 단 하루! 하루 10분컷 5%할인 (~6/2)                                1
# [무료수강권] RED 검수용_공정필 PM님                                     1
# [서포터즈 전용] 재무/세무 회계 실무 완성 무료 수강                              1
# [재결제쿠폰]초격차 패키지 : 한 번에 끝내는 node.js 웹 프로그래밍                   1
# Name: coupon_title, Length: 494, dtype: int64

# %%
df['category_title'].replace('데이터 사이언스','데이터사이언스',inplace=True)
df['category_title'].value_counts()
# Out:
# 프로그래밍      34430
# 데이터사이언스    14085
# 업무 생산성     13323
# 디자인        12009
# 영상/3D      10260
# 마케팅         9857
# 부동산/금융      5523
# 투자/재테크      2501
# 크리에이티브      2250
# 교육          1031
# 지식콘텐츠         56
# 비즈니스          42
# 파이낸스          25
# 관리             2
# 일러스트           1
# Name: category_title, dtype: int64

# %%
# 강의별 거래 횟수
plt.figure(figsize=(20,10))
sns.countplot(data=df, x='category_title')

# %%
# 강의별 거래액
plt.figure(figsize=(20,10))
sns.barplot(x='category_title',y='transaction_amount', data=df, estimator=np.sum)

# %%
# 강의별 평균 거래액
plt.figure(figsize=(20,10))
sns.barplot(x='category_title',y='transaction_amount', data=df, estimator=np.mean)

# %%
pd.pivot_table(
    data=df,
    values='transaction_amount',
    columns='category_title',
    aggfunc=np.mean
)
# Out:
# category_title            관리            교육        데이터사이언스            디자인  \
# transaction_amount  150000.0  1.238346e+06  198895.578559  122579.884087
#
# category_title                마케팅         부동산/금융           비즈니스        업무 생산성  \
# transaction_amount  151593.587704  171408.674452  274148.095238  90854.526383
#
# category_title              영상/3D      일러스트          지식콘텐츠         크리에이티브  \
# transaction_amount  107006.976608  208000.0  228160.714286  368952.678667
#
# category_title             투자/재테크      파이낸스          프로그래밍
# transaction_amount  191769.190324  283200.0  109669.452019

# %%
df[df['category_title']=='교육']
# Out:
#         Unnamed: 0       id  customer_id  course_id     type      state  \
# 98              98   970949     474219.0   204387.0    ORDER  CANCELLED
# 110            110   970745     478087.0   204387.0    ORDER  CANCELLED
# 169            169   971168     478266.0   204387.0    ORDER  CANCELLED
# 384            384   971672     478457.0   204387.0    ORDER  CANCELLED
# 631            631   972364     478743.0   204039.0  PAYMENT  COMPLETED
# ...            ...      ...          ...        ...      ...        ...
# 104859      104859  1361140     107470.0   207326.0  PAYMENT  CANCELLED
# 104905      104905  1367252     672301.0   207714.0  PAYMENT  COMPLETED
# 105163      105163  1367258     672307.0   207731.0  PAYMENT  COMPLETED
# 105174      105174  1363720      29356.0   207729.0  PAYMENT  CANCELLED
# 105265      105265  1367259     672308.0   207742.0  PAYMENT  COMPLETED
#
#                                 course_title category_title   format  \
# 98                   (B2B) 현대백화점 온라인 구독 올 플랜             교육  B2B 온라인
# 110                  (B2B) 현대백화점 온라인 구독 올 플랜             교육  B2B 온라인
# 169                  (B2B) 현대백화점 온라인 구독 올 플랜             교육  B2B 온라인
# 384                  (B2B) 현대백화점 온라인 구독 올 플랜             교육  B2B 온라인
# 631          (B2B) 힐코코리아 온라인 구독 올 플랜 - 패파입주사             교육  B2B 온라인
# ...                                      ...            ...      ...
# 104859         (B2B) 한남대학교 2021년 가을학기 온라인 구독             교육  B2B 온라인
# 104905  (B2B) (주)공정씨컴퍼니 온라인 구독 올 플랜 - 비대면바우처             교육  B2B 온라인
# 105163      (B2B) 그린오션스 온라인 구독 올 플랜 - 비대면바우처             교육  B2B 온라인
# 105174       (B2B) 디캠프 패밀리사 온라인 구독 올 플랜 (9월)             교육  B2B 온라인
# 105265      (B2B) (주)오디 온라인 구독 올 플랜 - 비대면바우처             교육  B2B 온라인
#
#                completed_at  transaction_amount coupon_title  \
# 98      2021-03-28 18:17:13              600000          NaN
# 110     2021-03-28 18:35:54              600000          NaN
# 169     2021-03-28 20:02:19              600000          NaN
# 384     2021-03-28 22:46:22              600000          NaN
# 631     2021-03-29 08:52:36              100000          NaN
# ...                     ...                 ...          ...
# 104859  2021-09-23 15:57:29              300000          NaN
# 104905  2021-09-23 17:33:18             2000000          NaN
# 105163  2021-09-24 14:26:08              600000          NaN
# 105174  2021-09-24 14:41:04              150000          NaN
# 105265  2021-09-24 18:17:10              600000          NaN
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg    method  \
# 98                         NaN    600000.0         600000.0     NaN      CARD
# 110                        NaN    600000.0         600000.0     NaN      CARD
# 169                        NaN    600000.0         600000.0     NaN      CARD
# 384                        NaN    600000.0         600000.0     NaN      CARD
# 631                        NaN         NaN              NaN     NaN  TRANSFER
# ...                        ...         ...              ...     ...       ...
# 104859                     NaN    300000.0         300000.0  INICIS      CARD
# 104905                     NaN         NaN              NaN     NaN    ONSITE
# 105163                     NaN         NaN              NaN     NaN    ONSITE
# 105174                     NaN    150000.0         150000.0  INICIS      CARD
# 105265                     NaN         NaN              NaN     NaN    ONSITE
#
#        subcategory_title marketing_start_at
# 98                   NaN                NaN
# 110                  NaN                NaN
# 169                  NaN                NaN
# 384                  NaN                NaN
# 631                  NaN                NaN
# ...                  ...                ...
# 104859               NaN                NaN
# 104905               NaN                NaN
# 105163               NaN                NaN
# 105174               NaN                NaN
# 105265               NaN                NaN
#
# [1031 rows x 19 columns]

# %%
#교육에 대한 데이터

# %%
df.groupby('category_title').mean()['transaction_amount'].sort_values(ascending=False)
# Out:
# category_title
# 교육         1.238346e+06
# 크리에이티브     3.689527e+05
# 파이낸스       2.832000e+05
# 비즈니스       2.741481e+05
# 지식콘텐츠      2.281607e+05
# 일러스트       2.080000e+05
# 데이터사이언스    1.988956e+05
# 투자/재테크     1.917692e+05
# 부동산/금융     1.714087e+05
# 마케팅        1.515936e+05
# 관리         1.500000e+05
# 디자인        1.225799e+05
# 프로그래밍      1.096695e+05
# 영상/3D      1.070070e+05
# 업무 생산성     9.085453e+04
# Name: transaction_amount, dtype: float64

# %%
df.head()
# Out:
#    Unnamed: 0      id  customer_id  course_id     type      state  \
# 0           0  970634     504760.0   201435.0    ORDER  CANCELLED
# 1           1  970650     432862.0   203178.0    ORDER  CANCELLED
# 2           2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 3           3  970656      72297.0   204246.0    ORDER  CANCELLED
# 4           4  970658     478028.0   201797.0  PAYMENT  COMPLETED
#
#                     course_title category_title  format         completed_at  \
# 0      올인원 패키지 : 알고리즘 기술면접 완전 정복          프로그래밍     올인원  2021-03-28 15:00:11
# 1    초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원  2021-03-28 15:16:53
# 2           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인  2021-03-28 15:21:43
# 3           시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인  2021-03-28 15:21:43
# 4  올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원  2021-03-28 15:21:54
#
#    transaction_amount              coupon_title  coupon_discount_amount  \
# 0               90500                       NaN                     NaN
# 1               96000                       NaN                     NaN
# 2              171810     [10% 할인] 시크릿코드 실무 완성편                 19090.0
# 3              171810                       NaN                     NaN
# 4               97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰                 20000.0
#
#    sale_price  tax_free_amount   pg method subcategory_title  \
# 0    110500.0         110500.0  NaN  VBANK           개발자 커리어
# 1    116000.0         116000.0  NaN   CARD             영상 편집
# 2    190900.0         190900.0  NaN   CARD               NaN
# 3    190900.0         190900.0  NaN   CARD               NaN
# 4    117500.0         117500.0  NaN   CARD           PPT/보고서
#
#     marketing_start_at
# 0                  NaN
# 1  2020-12-02 00:00:00
# 2  2021-03-04 00:00:00
# 3  2021-03-04 00:00:00
# 4  2019-11-14 00:00:00

# %%
# 무조건 전처리 해야 하는 항목들
# type & state 컬럼

# %%
df['state'].value_counts()
# Out:
# COMPLETED    62763
# CANCELLED    41279
# PENDING       1144
# DELETED        219
# REQUESTED       14
# Name: state, dtype: int64

# %%
df.loc[df['customer_id'] == 172881]
# Out:
#      Unnamed: 0      id  customer_id  course_id     type      state  \
# 152         152  971126     172881.0   201998.0    ORDER  CANCELLED
# 161         161  971156     172881.0   201998.0  PAYMENT    PENDING
#
#            course_title category_title format         completed_at  \
# 152  올인원 패키지 : iOS 앱 개발          프로그래밍    올인원  2021-03-28 19:48:17
# 161  올인원 패키지 : iOS 앱 개발          프로그래밍    올인원  2021-03-28 19:55:58
#
#      transaction_amount coupon_title  coupon_discount_amount  sale_price  \
# 152              110500          NaN                     NaN    110500.0
# 161              110500          NaN                     NaN    110500.0
#
#      tax_free_amount   pg method subcategory_title   marketing_start_at
# 152         110500.0  NaN  VBANK              모바일앱  2020-01-14 00:00:00
# 161         110500.0  NaN  VBANK              모바일앱  2020-01-14 00:00:00

# %%
df.loc[df['customer_id'] == 478246]
# Out:
#      Unnamed: 0      id  customer_id  course_id     type      state  \
# 157         157  971143     478246.0   203178.0  PAYMENT  COMPLETED
# 158         158  971130     478246.0   203178.0    ORDER  CANCELLED
#
#                     course_title category_title format         completed_at  \
# 157  초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원  2021-03-28 19:51:41
# 158  초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원  2021-03-28 19:51:59
#
#      transaction_amount coupon_title  coupon_discount_amount  sale_price  \
# 157              116000          NaN                     NaN    116000.0
# 158              116000          NaN                     NaN    116000.0
#
#      tax_free_amount   pg method subcategory_title   marketing_start_at
# 157         116000.0  NaN   CARD             영상 편집  2020-12-02 00:00:00
# 158         116000.0  NaN   CARD             영상 편집  2020-12-02 00:00:00

# %%
df_com = df.loc[df['state'] == 'COMPLETED']
df_com.count()
# Out:
# Unnamed: 0                62763
# id                        62763
# customer_id               62760
# course_id                 60233
# type                      62763
# state                     62763
# course_title              62759
# category_title            62755
# format                    62759
# completed_at              62763
# transaction_amount        62763
# coupon_title              23801
# coupon_discount_amount    23801
# sale_price                61680
# tax_free_amount           61680
# pg                        52409
# method                    60194
# subcategory_title         51804
# marketing_start_at        51751
# dtype: int64

# %% [markdown]
# ## type 과 state 컬럼 고려한 전처리

# %%
df['type'].value_counts(), df['state'].value_counts()
# Out:
# (PAYMENT        61433
#  ORDER          40159
#  REFUND          3824
#  TRANSACTION        3
#  Name: type, dtype: int64, COMPLETED    62763
#  CANCELLED    41279
#  PENDING       1144
#  DELETED        219
#  REQUESTED       14
#  Name: state, dtype: int64)

# %% [markdown]
#     state = order
#     옛날에 사용하던 양식으로 불필요한 데이터이기에
#     해당 로우 제외한다

# %%
# state = order 제외
df_new = df[df['type'] != 'ORDER']
df_new.shape
# Out:
# (65260, 19)

# %%
# df_new['type'].unique()
df_new = df[(df['type'] == 'PAYMENT') |(df['type'] == 'REFUND')]

# %%
df_new['type'].unique()
# Out:
# array(['PAYMENT', 'REFUND'], dtype=object)

# %%
df_new =df_new[(df_new['state'] == 'REQUESTED') | (df_new['state'] == 'COMPLETED')]
# df_new =df[df['state'] == 'COMPLETED'

# %%
df_new['state'].unique()
# Out:
# array(['COMPLETED', 'REQUESTED'], dtype=object)

# %%
df_new['state'].value_counts()
# Out:
# COMPLETED    56724
# REQUESTED       14
# Name: state, dtype: int64

# %%
df_new = df_new[~((df_new['coupon_discount_amount'] > df_new['sale_price']) & (df_new['transaction_amount'] > 0))]

# %%
df_new
# Out:
#         Unnamed: 0       id  customer_id  course_id     type      state  \
# 2                2   970657      72297.0   204246.0  PAYMENT  COMPLETED
# 4                4   970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8                8   970669     478033.0   203178.0  PAYMENT  COMPLETED
# 10              10   970671     469860.0   203644.0  PAYMENT  COMPLETED
# 14              14   970676     478035.0   203720.0  PAYMENT  COMPLETED
# ...            ...      ...          ...        ...      ...        ...
# 105411      105411  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 105412      105412  1364976     384003.0   203178.0  PAYMENT  COMPLETED
# 105413      105413  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 105416      105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105418      105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                           course_title category_title  format  \
# 2                                 시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4                        올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 8                          초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 10      올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초(평생소장)         부동산/금융     올인원
# 14                         초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍     올인원
# ...                                                ...            ...     ...
# 105411                      초격차 패키지 : 한번에 끝내는 3D 디자인 툴            디자인     올인원
# 105412                     초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 105413                     초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍     올인원
# 105416                 초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D     올인원
# 105418                              용호수의 돈 버는 실전 영상 제작          영상/3D     올인원
#
#                completed_at  transaction_amount               coupon_title  \
# 2       2021-03-28 15:21:43              171810      [10% 할인] 시크릿코드 실무 완성편
# 4       2021-03-28 15:21:54               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 8       2021-03-28 15:26:47               96000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 10      2021-03-28 15:27:17              263000                        NaN
# 14      2021-03-28 15:31:01               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# ...                     ...                 ...                        ...
# 105411  2021-09-25 13:39:26              212000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105412  2021-09-25 13:46:29              149000                        NaN
# 105413  2021-09-25 14:01:26              159000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105416  2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105418  2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 2                      19090.0    190900.0         190900.0     NaN   CARD
# 4                      20000.0    117500.0         117500.0     NaN   CARD
# 8                      20000.0    116000.0         116000.0     NaN   CARD
# 10                         NaN    263000.0         263000.0     NaN   CARD
# 14                     20000.0    111000.0         111000.0     NaN   CARD
# ...                        ...         ...              ...     ...    ...
# 105411                 20000.0    232000.0         232000.0  INICIS   CARD
# 105412                     NaN    149000.0         149000.0   KAKAO   CARD
# 105413                 20000.0    179000.0         179000.0  INICIS   CARD
# 105416                 20000.0    116000.0         116000.0  INICIS  VBANK
# 105418                 30000.0    169000.0         169000.0   NAVER  POINT
#
#        subcategory_title   marketing_start_at
# 2                    NaN  2021-03-04 00:00:00
# 4                PPT/보고서  2019-11-14 00:00:00
# 8                  영상 편집  2020-12-02 00:00:00
# 10                   NaN  2020-11-27 00:00:00
# 14              프론트엔드 개발  2021-02-02 00:00:00
# ...                  ...                  ...
# 105411              디자인툴  2021-04-23 00:00:00
# 105412             영상 편집  2020-12-02 00:00:00
# 105413            백엔드 개발  2021-05-31 00:00:00
# 105416             영상 편집  2021-06-15 00:00:00
# 105418             영상 편집  2021-08-17 00:00:00
#
# [56735 rows x 19 columns]

# %% [markdown]
# ## 카테고리별 매출 및 판매량 추이

# %%
df_new.head()
# Out:
#     Unnamed: 0      id  customer_id  course_id     type      state  \
# 2            2  970657      72297.0   204246.0  PAYMENT  COMPLETED
# 4            4  970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8            8  970669     478033.0   203178.0  PAYMENT  COMPLETED
# 10          10  970671     469860.0   203644.0  PAYMENT  COMPLETED
# 14          14  970676     478035.0   203720.0  PAYMENT  COMPLETED
#
#                                       course_title category_title  format  \
# 2                             시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4                    올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 8                      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 10  올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초(평생소장)         부동산/금융     올인원
# 14                     초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍     올인원
#
#            completed_at  transaction_amount              coupon_title  \
# 2   2021-03-28 15:21:43              171810     [10% 할인] 시크릿코드 실무 완성편
# 4   2021-03-28 15:21:54               97500  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 8   2021-03-28 15:26:47               96000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 10  2021-03-28 15:27:17              263000                       NaN
# 14  2021-03-28 15:31:01               91000  [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
#
#     coupon_discount_amount  sale_price  tax_free_amount   pg method  \
# 2                  19090.0    190900.0         190900.0  NaN   CARD
# 4                  20000.0    117500.0         117500.0  NaN   CARD
# 8                  20000.0    116000.0         116000.0  NaN   CARD
# 10                     NaN    263000.0         263000.0  NaN   CARD
# 14                 20000.0    111000.0         111000.0  NaN   CARD
#
#    subcategory_title   marketing_start_at
# 2                NaN  2021-03-04 00:00:00
# 4            PPT/보고서  2019-11-14 00:00:00
# 8              영상 편집  2020-12-02 00:00:00
# 10               NaN  2020-11-27 00:00:00
# 14          프론트엔드 개발  2021-02-02 00:00:00

# %%
# 강의별 거래 횟수
plt.figure(figsize=(20,10))
sns.countplot(data=df_new, x='category_title')

# %%
# 강의별 거래액
plt.figure(figsize=(20,10))
sns.barplot(x='category_title',y='transaction_amount', data=df_new, estimator=np.sum)

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56735 entries, 2 to 105418
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              56735 non-null  int64
#  1   id                      56735 non-null  int64
#  2   customer_id             56735 non-null  float64
#  3   course_id               54579 non-null  float64
#  4   type                    56735 non-null  object
#  5   state                   56735 non-null  object
#  6   course_title            56734 non-null  object
#  7   category_title          56731 non-null  object
#  8   format                  56734 non-null  object
#  9   completed_at            56735 non-null  object
#  10  transaction_amount      56735 non-null  int64
#  11  coupon_title            23760 non-null  object
#  12  coupon_discount_amount  23760 non-null  float64
#  13  sale_price              55655 non-null  float64
#  14  tax_free_amount         55655 non-null  float64
#  15  pg                      46384 non-null  object
#  16  method                  56731 non-null  object
#  17  subcategory_title       46428 non-null  object
#  18  marketing_start_at      46680 non-null  object
# dtypes: float64(5), int64(3), object(11)
# memory usage: 10.7+ MB

# %%
df_new['completed_at'] = pd.to_datetime(df_new['completed_at'])
df_new[df_new['completed_at'].dt.month==9]
# Out:
#         Unnamed: 0       id  customer_id  course_id     type      state  \
# 96918        96918  1322898      70833.0   203178.0  PAYMENT  COMPLETED
# 96919        96919  1322895     639153.0   203935.0  PAYMENT  COMPLETED
# 96921        96921  1322906     623732.0   203935.0  PAYMENT  COMPLETED
# 96923        96923  1322937     651158.0   206181.0  PAYMENT  COMPLETED
# 96925        96925  1322943     527720.0        NaN  PAYMENT  COMPLETED
# ...            ...      ...          ...        ...      ...        ...
# 105411      105411  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 105412      105412  1364976     384003.0   203178.0  PAYMENT  COMPLETED
# 105413      105413  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 105416      105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105418      105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                                      course_title category_title format  \
# 96918                 초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원
# 96919                 초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍    올인원
# 96921                 초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍    올인원
# 96923               올인원 패키지 : 리마의 로맨스판타지 웹소설 일러스트            디자인    올인원
# 96925   프로모션 : 상상을 현실로 만드는 VFX 벼락치기 패키지 (9월 프리패스)         크리에이티브    올인원
# ...                                           ...            ...    ...
# 105411                 초격차 패키지 : 한번에 끝내는 3D 디자인 툴            디자인    올인원
# 105412                초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원
# 105413                초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍    올인원
# 105416            초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D    올인원
# 105418                         용호수의 돈 버는 실전 영상 제작          영상/3D    올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 96918  2021-09-01 00:03:49              149000                        NaN
# 96919  2021-09-01 00:04:15              159000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 96921  2021-09-01 00:06:41              169000  [WELCOME] 온라인 강의 1만원 할인쿠폰
# 96923  2021-09-01 00:16:31              159000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 96925  2021-09-01 00:19:19              330000                        NaN
# ...                    ...                 ...                        ...
# 105411 2021-09-25 13:39:26              212000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105412 2021-09-25 13:46:29              149000                        NaN
# 105413 2021-09-25 14:01:26              159000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105416 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105418 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 96918                      NaN    149000.0         149000.0  INICIS   CARD
# 96919                  20000.0    179000.0         179000.0  INICIS   CARD
# 96921                  10000.0    179000.0         179000.0  INICIS  TRANS
# 96923                  20000.0    179000.0         179000.0  INICIS   CARD
# 96925                      NaN    330000.0         330000.0  INICIS   CARD
# ...                        ...         ...              ...     ...    ...
# 105411                 20000.0    232000.0         232000.0  INICIS   CARD
# 105412                     NaN    149000.0         149000.0   KAKAO   CARD
# 105413                 20000.0    179000.0         179000.0  INICIS   CARD
# 105416                 20000.0    116000.0         116000.0  INICIS  VBANK
# 105418                 30000.0    169000.0         169000.0   NAVER  POINT
#
#        subcategory_title   marketing_start_at
# 96918              영상 편집  2020-12-02 00:00:00
# 96919             백엔드 개발  2021-05-31 00:00:00
# 96921             백엔드 개발  2021-05-31 00:00:00
# 96923               일러스트  2021-08-30 00:00:00
# 96925                NaN                  NaN
# ...                  ...                  ...
# 105411              디자인툴  2021-04-23 00:00:00
# 105412             영상 편집  2020-12-02 00:00:00
# 105413            백엔드 개발  2021-05-31 00:00:00
# 105416             영상 편집  2021-06-15 00:00:00
# 105418             영상 편집  2021-08-17 00:00:00
#
# [6244 rows x 19 columns]

# %%
# 강의별 거래 횟수
plt.figure(figsize=(20,10))
sns.countplot(data=df_new, x='category_title')

# %%
## 달별로 그룹화하기
df_new_month = df_new.copy()
df_new_month['month'] = [k for k in df_new['completed_at'].dt.month] ## 요일 칼럼
df_new_month.tail()
# Out:
#         Unnamed: 0       id  customer_id  course_id     type      state  \
# 105411      105411  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 105412      105412  1364976     384003.0   203178.0  PAYMENT  COMPLETED
# 105413      105413  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 105416      105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105418      105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                            course_title category_title format  \
# 105411       초격차 패키지 : 한번에 끝내는 3D 디자인 툴            디자인    올인원
# 105412      초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D    올인원
# 105413      초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍    올인원
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D    올인원
# 105418               용호수의 돈 버는 실전 영상 제작          영상/3D    올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 105411 2021-09-25 13:39:26              212000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105412 2021-09-25 13:46:29              149000                        NaN
# 105413 2021-09-25 14:01:26              159000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105416 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105418 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 105411                 20000.0    232000.0         232000.0  INICIS   CARD
# 105412                     NaN    149000.0         149000.0   KAKAO   CARD
# 105413                 20000.0    179000.0         179000.0  INICIS   CARD
# 105416                 20000.0    116000.0         116000.0  INICIS  VBANK
# 105418                 30000.0    169000.0         169000.0   NAVER  POINT
#
#        subcategory_title   marketing_start_at  month
# 105411              디자인툴  2021-04-23 00:00:00      9
# 105412             영상 편집  2020-12-02 00:00:00      9
# 105413            백엔드 개발  2021-05-31 00:00:00      9
# 105416             영상 편집  2021-06-15 00:00:00      9
# 105418             영상 편집  2021-08-17 00:00:00      9

# %%
# 월별 거래 횟수
sns.set(rc={'figure.figsize':(15, 5)})
plt.figure(figsize=(20,10))
plt.rc('font', family='NanumBarunGothic')
sns.countplot(data=df_new_month, x='month', hue = 'category_title')

# %%
type(df_new_month['category_title'].unique()[11])
category = list(df_new_month['category_title'].unique())
category.pop(11)
category
# Out:
# ['프로그래밍',
#  '업무 생산성',
#  '영상/3D',
#  '부동산/금융',
#  '데이터사이언스',
#  '디자인',
#  '마케팅',
#  '크리에이티브',
#  '투자/재테크',
#  '교육',
#  '관리',
#  '비즈니스',
#  '지식콘텐츠',
#  '파이낸스']

# %%
sns.countplot(data = df_new_month[df_new_month['category_title'] == '비즈니스' ], x='month')

# %%
sns.set(rc={'figure.figsize':(20, 20)})
plt.figure(figsize=(30,20))
for i in range(len(category)):
    plt.subplot(3,5,i+1)
    plt.rc('font', family='NanumBarunGothic')
    ax = sns.countplot(data = df_new_month[ df_new_month['category_title'] == category[i] ], x='month')
    ax.set_title(category[i])
plt.figure
# Out:
# <function matplotlib.pyplot.figure>
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48141 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 44536 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 47000 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 48141 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ---------------------------------------------------------
#
# ---

# %%
df_marketing_st = df_new[(df_new['marketing_start_at'].isnull())]

# %%
df_new.columns
# Out:
# Index(['Unnamed: 0', 'id', 'customer_id', 'course_id', 'type', 'state',
#        'course_title', 'category_title', 'format', 'completed_at',
#        'transaction_amount', 'coupon_title', 'coupon_discount_amount',
#        'sale_price', 'tax_free_amount', 'pg', 'method', 'subcategory_title',
#        'marketing_start_at'],
#       dtype='object')

# %%
# sales price / transaction price 
# coupon price가 없는데, sales price != transaction price 인 경우, 포인트로 사용한 것이다. -> 
df_new['point_amount'] = df_new[df_new['coupon_discount_amount'].isnull()]['sale_price']-df_new[df_new['coupon_discount_amount'].isnull()]['transaction_amount']

# %%
df_new[~df_new['coupon_discount_amount'].isnull()]
# Out:
#         Unnamed: 0       id  customer_id  course_id     type      state  \
# 2                2   970657      72297.0   204246.0  PAYMENT  COMPLETED
# 4                4   970658     478028.0   201797.0  PAYMENT  COMPLETED
# 8                8   970669     478033.0   203178.0  PAYMENT  COMPLETED
# 14              14   970676     478035.0   203720.0  PAYMENT  COMPLETED
# 28              28   970704     471759.0   204068.0  PAYMENT  COMPLETED
# ...            ...      ...          ...        ...      ...        ...
# 105403      105403  1364919     670833.0   201582.0  PAYMENT  COMPLETED
# 105411      105411  1364969     669238.0   204286.0  PAYMENT  COMPLETED
# 105413      105413  1364991     670891.0   203935.0  PAYMENT  COMPLETED
# 105416      105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
# 105418      105418  1365007     610626.0   206720.0  PAYMENT  COMPLETED
#
#                            course_title category_title  format  \
# 2                  시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 4         올인원 패키지 : 직장인 필수 스킬 3종 세트 MAX         업무 생산성     올인원
# 8           초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 14          초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍     올인원
# 28           올인원 패키지 : 마디아의 UX/UI 포트폴리오            디자인     올인원
# ...                                 ...            ...     ...
# 105403           올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍     올인원
# 105411       초격차 패키지 : 한번에 끝내는 3D 디자인 툴            디자인     올인원
# 105413      초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍     올인원
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D     올인원
# 105418               용호수의 돈 버는 실전 영상 제작          영상/3D     올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 2      2021-03-28 15:21:43              171810      [10% 할인] 시크릿코드 실무 완성편
# 4      2021-03-28 15:21:54               97500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 8      2021-03-28 15:26:47               96000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 14     2021-03-28 15:31:01               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 28     2021-03-28 15:46:22               89000   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰
# ...                    ...                 ...                        ...
# 105403 2021-09-25 12:08:05              169000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105411 2021-09-25 13:39:26              212000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105413 2021-09-25 14:01:26              159000    [미래투자금] 온라인 강의 2만원 할인쿠폰
# 105416 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
# 105418 2021-09-25 14:25:47              139000  [WELCOME] 온라인 강의 3만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 2                      19090.0    190900.0         190900.0     NaN   CARD
# 4                      20000.0    117500.0         117500.0     NaN   CARD
# 8                      20000.0    116000.0         116000.0     NaN   CARD
# 14                     20000.0    111000.0         111000.0     NaN   CARD
# 28                     10000.0     99000.0          99000.0     NaN   CARD
# ...                        ...         ...              ...     ...    ...
# 105403                 20000.0    189000.0         189000.0  INICIS   CARD
# 105411                 20000.0    232000.0         232000.0  INICIS   CARD
# 105413                 20000.0    179000.0         179000.0  INICIS   CARD
# 105416                 20000.0    116000.0         116000.0  INICIS  VBANK
# 105418                 30000.0    169000.0         169000.0   NAVER  POINT
#
#        subcategory_title   marketing_start_at  point_amount
# 2                    NaN  2021-03-04 00:00:00           NaN
# 4                PPT/보고서  2019-11-14 00:00:00           NaN
# 8                  영상 편집  2020-12-02 00:00:00           NaN
# 14              프론트엔드 개발  2021-02-02 00:00:00           NaN
# 28                 UX/UI  2021-03-11 00:00:00           NaN
# ...                  ...                  ...           ...
# 105403           개발자 커리어  2019-09-30 00:00:00           NaN
# 105411              디자인툴  2021-04-23 00:00:00           NaN
# 105413            백엔드 개발  2021-05-31 00:00:00           NaN
# 105416             영상 편집  2021-06-15 00:00:00           NaN
# 105418             영상 편집  2021-08-17 00:00:00           NaN
#
# [23760 rows x 20 columns]

# %%
# coupon 도 쓰고, point도 쓴 사람이 있나?
# coupon_discount_amount + transaction_amount != sale_price
df_new[(df_new['coupon_discount_amount']+df_new['transaction_amount'] != df_new['sale_price'])&(df_new['point_amount'].isnull()) & (df_new['coupon_discount_amount'] < df_new['sale_price'])]
# coupon_discount_amount가 실제 할인 금액이랑 다른 경우가 존재한다.
# Out:
#        Unnamed: 0       id  customer_id  course_id     type      state  \
# 51427       51427  1129951     496508.0   202677.0  PAYMENT  COMPLETED
# 51628       51628  1130758     537729.0   205162.0  PAYMENT  COMPLETED
# 51633       51633  1130768     177386.0   205162.0  PAYMENT  COMPLETED
# 59098       59098  1158171      55189.0   202545.0  PAYMENT  COMPLETED
# 60202       60202  1163189     571540.0   203935.0  PAYMENT  COMPLETED
# 60786       60786  1166465     572618.0   205053.0  PAYMENT  COMPLETED
# 60788       60788  1166466     135344.0   201582.0  PAYMENT  COMPLETED
# 62051       62051  1170396     574636.0   203523.0  PAYMENT  COMPLETED
# 62055       62055  1170415     574601.0   203720.0  PAYMENT  COMPLETED
# 62062       62062  1170432     400694.0   203942.0  PAYMENT  COMPLETED
# 62071       62071  1170452     569502.0   203787.0  PAYMENT  COMPLETED
# 62072       62072  1170457     556056.0   203720.0  PAYMENT  COMPLETED
# 62086       62086  1170445     556404.0   203178.0  PAYMENT  COMPLETED
# 66934       66934  1184430     390054.0   205548.0  PAYMENT  COMPLETED
# 66964       66964  1184511     390054.0   203935.0  PAYMENT  COMPLETED
# 67033       67033  1184719     162948.0   205162.0  PAYMENT  COMPLETED
#
#                                             course_title category_title  \
# 51427                                REC.ON : 틱톡(TikTok)            마케팅
# 51628  올인원 패키지 : 아카데미 : 편집하는여자의 영상편집 마스터클래스 - 제 1강 프리...          영상/3D
# 51633  올인원 패키지 : 아카데미 : 편집하는여자의 영상편집 마스터클래스 - 제 1강 프리...          영상/3D
# 59098                                 올인원 패키지 : 부동산 디벨로퍼         부동산/금융
# 60202                        초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍
# 60786  올인원 패키지 : 권오상의 금융 아카데미 - 권오상의 재무제표 분석 기초 (수강시간...         부동산/금융
# 60788                             올인원 패키지 : 컴퓨터 공학 전공 필수          프로그래밍
# 62051                        초격차 패키지 : 한번에 끝내는 UX/UI 디자인            디자인
# 62055                        초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍
# 62062   초격차 패키지 : 30개 프로젝트로 배우는 Android 앱 개발 with Kotlin          프로그래밍
# 62071                            초격차 패키지 : 한번에 끝내는 디자인 툴            디자인
# 62072                        초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍
# 62086                        초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D
# 66934                          초격차 패키지 : 한 번에 끝내는 데이터 분석        데이터사이언스
# 66964                        초격차 패키지 : 한 번에 끝내는 파이썬 웹 개발          프로그래밍
# 67033  올인원 패키지 : 아카데미 : 편집하는여자의 영상편집 마스터클래스 - 제 1강 프리...          영상/3D
#
#       format        completed_at  transaction_amount  \
# 51427    올인원 2021-06-09 16:23:26                   0
# 51628    올인원 2021-06-09 23:32:47               78400
# 51633    올인원 2021-06-09 23:40:33               78400
# 59098    올인원 2021-06-22 23:39:16              138000
# 60202    올인원 2021-06-24 23:46:24               89000
# 60786    올인원 2021-06-25 23:56:52              250000
# 60788    올인원 2021-06-25 23:56:56              121500
# 62051    올인원 2021-06-27 23:37:54              159000
# 62055    올인원 2021-06-27 23:43:24              106000
# 62062    올인원 2021-06-27 23:51:12              102000
# 62071    올인원 2021-06-27 23:57:17              166000
# 62072    올인원 2021-06-27 23:59:11              106000
# 62086    올인원 2021-06-28 00:13:41              112000
# 66934    올인원 2021-06-30 23:49:07               71200
# 66964    올인원 2021-06-30 23:51:48               69300
# 67033    올인원 2021-06-30 23:58:15               78400
#
#                         coupon_title  coupon_discount_amount  sale_price  \
# 51427    [테스트쿠폰] 네이버 페이 간편결제 테스트용 쿠폰                 92910.0     93000.0
# 51628        [시크릿쿠폰] 편집하는여자 20% 할인쿠폰                 39200.0     98000.0
# 51633        [시크릿쿠폰] 편집하는여자 20% 할인쿠폰                 39200.0     98000.0
# 59098     [일주일한정] 플러스 친구 1만원 즉시할인 쿠폰                 20000.0    148000.0
# 60202     [일주일한정] 플러스 친구 1만원 즉시할인 쿠폰                 20000.0     99000.0
# 60786     [일주일한정] 플러스 친구 1만원 즉시할인 쿠폰                 20000.0    260000.0
# 60788     [일주일한정] 플러스 친구 1만원 즉시할인 쿠폰                 20000.0    131500.0
# 62051     [일주일한정] 플러스 친구 1만원 즉시할인 쿠폰                 20000.0    169000.0
# 62055     [일주일한정] 플러스 친구 1만원 즉시할인 쿠폰                 20000.0    116000.0
# 62062     [일주일한정] 플러스 친구 1만원 즉시할인 쿠폰                 20000.0    112000.0
# 62071     [일주일한정] 플러스 친구 1만원 즉시할인 쿠폰                 20000.0    176000.0
# 62072     [일주일한정] 플러스 친구 1만원 즉시할인 쿠폰                 20000.0    116000.0
# 62086     [일주일한정] 플러스 친구 1만원 즉시할인 쿠폰                 20000.0    122000.0
# 66934          [20%할인]데이터 분석 초격차 패키지                 35600.0     89000.0
# 66964  [특별쿠폰] 올인원 패키지 : 파이썬 웹 개발 구매자                 59400.0     99000.0
# 67033        [시크릿쿠폰] 편집하는여자 20% 할인쿠폰                 39200.0     98000.0
#
#        tax_free_amount      pg     method subcategory_title  \
# 51427          93000.0     NaN  PROMOTION            SNS마케팅
# 51628          98000.0  INICIS       CARD             영상 편집
# 51633          98000.0  INICIS       CARD             영상 편집
# 59098         148000.0  INICIS       CARD            부동산 개발
# 60202          99000.0   NAVER       CARD            백엔드 개발
# 60786         260000.0  INICIS       CARD          회계/재무/세무
# 60788         131500.0  INICIS       CARD           개발자 커리어
# 62051         169000.0  INICIS      VBANK             UX/UI
# 62055         116000.0   KAKAO       CARD          프론트엔드 개발
# 62062         112000.0   PAYCO       CARD              모바일앱
# 62071         176000.0   NAVER       CARD              디자인툴
# 62072         116000.0   PAYCO       CARD          프론트엔드 개발
# 62086         122000.0  INICIS      VBANK             영상 편집
# 66934          89000.0   PAYCO       CARD             데이터분석
# 66964          99000.0   PAYCO       CARD            백엔드 개발
# 67033          98000.0  INICIS       CARD             영상 편집
#
#         marketing_start_at  point_amount
# 51427  2020-07-24 00:00:00           NaN
# 51628  2021-06-03 00:00:00           NaN
# 51633  2021-06-03 00:00:00           NaN
# 59098  2020-03-31 00:00:00           NaN
# 60202  2021-05-31 00:00:00           NaN
# 60786  2021-04-22 00:00:00           NaN
# 60788  2019-09-30 00:00:00           NaN
# 62051  2020-12-18 00:00:00           NaN
# 62055  2021-02-02 00:00:00           NaN
# 62062  2021-02-25 00:00:00           NaN
# 62071  2020-12-24 11:00:00           NaN
# 62072  2021-02-02 00:00:00           NaN
# 62086  2020-12-02 00:00:00           NaN
# 66934  2021-06-17 00:00:00           NaN
# 66964  2021-05-31 00:00:00           NaN
# 67033  2021-06-03 00:00:00           NaN

# %%
df_new[df_new['customer_id'] == 640697]
# Out:
#         Unnamed: 0       id  customer_id  course_id     type      state  \
# 105416      105416  1364996     640697.0   205365.0  PAYMENT  COMPLETED
#
#                            course_title category_title format  \
# 105416  초격차 패키지 : 한 번에 끝내는 유튜브 크리에이터 되기          영상/3D    올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 105416 2021-09-25 14:17:41               96000  [WELCOME] 온라인 강의 2만원 할인쿠폰
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 105416                 20000.0    116000.0         116000.0  INICIS  VBANK
#
#        subcategory_title   marketing_start_at  point_amount
# 105416             영상 편집  2021-06-15 00:00:00           NaN

# %%
df_new[df_new['customer_id'] == 670896]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, customer_id, course_id, type, state, course_title, category_title, format, completed_at, transaction_amount, coupon_title, coupon_discount_amount, sale_price, tax_free_amount, pg, method, subcategory_title, marketing_start_at, point_amount]
# Index: []

# %%
# 중복되는 customer_id 존재
df_new[df_new.duplicated('customer_id',keep=False)]
# Out:
#         Unnamed: 0       id  customer_id  course_id     type      state  \
# 2                2   970657      72297.0   204246.0  PAYMENT  COMPLETED
# 14              14   970676     478035.0   203720.0  PAYMENT  COMPLETED
# 28              28   970704     471759.0   204068.0  PAYMENT  COMPLETED
# 40              40   970730     445723.0   203720.0  PAYMENT  COMPLETED
# 46              46   970740     474451.0   202883.0  PAYMENT  COMPLETED
# ...            ...      ...          ...        ...      ...        ...
# 105387      105387  1364842     638903.0   206720.0  PAYMENT  COMPLETED
# 105393      105393  1364869     638903.0   203178.0  PAYMENT  COMPLETED
# 105399      105399  1364889      46138.0   206224.0  PAYMENT  COMPLETED
# 105406      105406  1364929     120686.0        NaN  PAYMENT  COMPLETED
# 105412      105412  1364976     384003.0   203178.0  PAYMENT  COMPLETED
#
#                         course_title category_title  format  \
# 2               시크릿코드 : 프론트엔드 실무 완성편          프로그래밍  스쿨 온라인
# 14       초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍     올인원
# 28        올인원 패키지 : 마디아의 UX/UI 포트폴리오            디자인     올인원
# 40       초격차 패키지 : 한 번에 끝내는 프론트엔드 개발          프로그래밍     올인원
# 46        올인원 패키지 : 디지털 마케팅 MAX 2020            마케팅     올인원
# ...                              ...            ...     ...
# 105387            용호수의 돈 버는 실전 영상 제작          영상/3D     올인원
# 105393   초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
# 105399  초격차 패키지 : 한 번에 끝내는 부동산 경매/공매         투자/재테크     올인원
# 105406    [한정판매] 자연어 A-Z 끝장 패키지(~9월)        데이터사이언스     올인원
# 105412   초격차 패키지 : 한번에 끝내는 영상 촬영과 편집          영상/3D     올인원
#
#               completed_at  transaction_amount               coupon_title  \
# 2      2021-03-28 15:21:43              171810      [10% 할인] 시크릿코드 실무 완성편
# 14     2021-03-28 15:31:01               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 28     2021-03-28 15:46:22               89000   [웰컴쿠폰] 올인원 패키지 1만원 할인 쿠폰
# 40     2021-03-28 16:15:46               91000   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# 46     2021-03-28 16:28:42              114500   [웰컴쿠폰] 올인원 패키지 2만원 할인 쿠폰
# ...                    ...                 ...                        ...
# 105387 2021-09-25 10:56:03              159000  [WELCOME] 온라인 강의 1만원 할인쿠폰
# 105393 2021-09-25 11:22:07              139000  [WELCOME] 온라인 강의 1만원 할인쿠폰
# 105399 2021-09-25 11:55:19              189000                        NaN
# 105406 2021-09-25 12:29:39              481000                        NaN
# 105412 2021-09-25 13:46:29              149000                        NaN
#
#         coupon_discount_amount  sale_price  tax_free_amount      pg method  \
# 2                      19090.0    190900.0         190900.0     NaN   CARD
# 14                     20000.0    111000.0         111000.0     NaN   CARD
# 28                     10000.0     99000.0          99000.0     NaN   CARD
# 40                     20000.0    111000.0         111000.0     NaN   CARD
# 46                     20000.0    134500.0         134500.0     NaN   CARD
# ...                        ...         ...              ...     ...    ...
# 105387                 10000.0    169000.0         169000.0   KAKAO  POINT
# 105393                 10000.0    149000.0         149000.0   KAKAO  POINT
# 105399                     NaN    189000.0         189000.0  INICIS   CARD
# 105406                     NaN    481000.0         481000.0  INICIS   CARD
# 105412                     NaN    149000.0         149000.0   KAKAO   CARD
#
#        subcategory_title   marketing_start_at  point_amount
# 2                    NaN  2021-03-04 00:00:00           NaN
# 14              프론트엔드 개발  2021-02-02 00:00:00           NaN
# 28                 UX/UI  2021-03-11 00:00:00           NaN
# 40              프론트엔드 개발  2021-02-02 00:00:00           NaN
# 46                디지털마케팅                  NaN           NaN
# ...                  ...                  ...           ...
# 105387             영상 편집  2021-08-17 00:00:00           NaN
# 105393             영상 편집  2020-12-02 00:00:00           NaN
# 105399            부동산 투자  2021-08-23 00:00:00           0.0
# 105406               NaN                  NaN           0.0
# 105412             영상 편집  2020-12-02 00:00:00           0.0
#
# [25413 rows x 20 columns]

# %%
df_cancel = df_new.loc[ (df_new['type'] =='PAYMENT') & (df_new['state']=='CANCELLED')]
df_cancel.head()

# %%
df_cancel.isnull().sum()

# %% [markdown]
#     type = PAYMENT
#     state = COMPLETED
#
#     확실하게 수익으로 잡힐 수 있는 것만 수익 데이터로써 활용한다.

# %%
# 수익 
df_rev = df.loc[ (df['type'] =='PAYMENT') & (df['state']=='COMPLETED')]

# %%
df_rev.head()

# %%
df_rev.shape
